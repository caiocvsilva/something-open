# %%
# !pip install inflect
# !pip install nltk
# Out:
# Collecting inflect
#   Obtaining dependency information for inflect from https://files.pythonhosted.org/packages/fb/c6/d9feb758be584f729424390af24687d3a4363d968164f94079f83cd536b4/inflect-7.0.0-py3-none-any.whl.metadata
#   Using cached inflect-7.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting pydantic>=1.9.1 (from inflect)
#   Obtaining dependency information for pydantic>=1.9.1 from https://files.pythonhosted.org/packages/e2/2c/9906b7abc337b0250a5634de5396e2f3cb1b837af0616424c2225a65aa80/pydantic-2.5.1-py3-none-any.whl.metadata
#   Downloading pydantic-2.5.1-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /home/caio/anaconda3/envs/osr/lib/python3.8/site-packages (from inflect) (4.7.1)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.9.1->inflect)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.3 (from pydantic>=1.9.1->inflect)
#   Obtaining dependency information for pydantic-core==2.14.3 from https://files.pythonhosted.org/packages/e1/e8/6137e62339a9810e4b7b87e8a81a9b395b5c350e8d18c0fa33ad46076ecc/pydantic_core-2.14.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pydantic_core-2.14.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Using cached inflect-7.0.0-py3-none-any.whl (34 kB)
# Downloading pydantic-2.5.1-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.6/381.6 kB 20.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 43.6 MB/s eta 0:00:0000:01
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Installing collected packages: pydantic-core, annotated-types, pydantic, inflect
# Successfully installed annotated-types-0.6.0 inflect-7.0.0 pydantic-2.5.1 pydantic-core-2.14.3
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting click (from nltk)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in /home/caio/anaconda3/envs/osr/lib/python3.8/site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/79/33/67c4ed826f5227655225c3feaaecd15afb8453e827334ddae95a7fba07ac/regex-2023.10.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading regex-2023.10.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/caio/anaconda3/envs/osr/lib/python3.8/site-packages (from nltk) (4.66.1)
# Downloading regex-2023.10.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.0/777.0 kB 21.6 MB/s eta 0:00:0000:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.7 nltk-3.8.1 regex-2023.10.3

# %%
import json
import sys
import pandas as pd
import random
import nltk
from itertools import chain
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('averaged_perceptron_tagger')   # Downloading the required NLTK model
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
p = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/caio/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/caio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/caio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/caio/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
json_file_name = 'misspelled_nouns.json'
with open(json_file_name, 'r') as json_file:
    misspelled_nouns = json.load(json_file)


json_file_name = 'corrected_nouns.json'
with open(json_file_name, 'r') as json_file:
    corrected_nouns = json.load(json_file)

# %%
def read_jsons():

    pool = []
    # Check if the user gave two arguments
    if len(sys.argv) != 3:
        print("Usage: python osar-jsons.py <json1> <json2>")
        sys.exit(1)

    # Open the first json
    with open(sys.argv[1]) as json_file:
        data1 = pd.json_normalize(json.load(json_file))
        pool.append(data1)

    # Open the second json
    with open(sys.argv[2]) as json_file:
        data2 = pd.json_normalize(json.load(json_file))
        pool.append(data2)

    return pd.concat(pool, ignore_index=True)

# A function that adds a new column to the dataframe pool called nouns
# for each existing row, the function will extract the nouns in the column placeholders
# and add to the new column
def extract_nouns(row):
    text_array = row['placeholders'] #Replace 'placeholders' with the actual name of the column containing your text data
    nouns = []
    blocked_strings = ['..', '.40', '/', '\\', ']','%', '‘','’']
    for text in text_array:
        tokens = nltk.word_tokenize(text)
        tagged = nltk.pos_tag(tokens)
        # nouns.extend([word.lower() for word, pos in tagged if (pos == 'NN' or pos == 'NNS' or pos == 'NNP' or pos == 'NNPS')])
        
        # iterate through the tagged words list and append singular nouns to the nouns list
        for word, pos in tagged:
            if (pos == 'NN' or pos == 'NNS' or pos == 'NNP' or pos == 'NNPS' or pos == 'VB') and (not word.isnumeric()) and (word not in blocked_strings) and ("'" not in word) and (len(word) > 1):
                # lemmatize the word to its singular form
                word = word.lower()
                word_s = p.lemmatize(word, pos='n')
                 # if the word is not changed into a singular form, keep it as it is
                if not word_s:
                    # nouns.append(word)
                    singular_noun = word
                else:
                    # nouns.append(word_s)
                    singular_noun = word_s
                if singular_noun in misspelled_nouns and corrected_nouns[misspelled_nouns.index(singular_noun)] is not None:
                    nouns.append(corrected_nouns[misspelled_nouns.index(singular_noun)])
                else:
                    nouns.append(singular_noun)

    return nouns


# A function that adds a new column to the dataframe pool called verbs
# for each existing row, the function will extract the verbs in the column template
# and add to the new column
def extract_verbs(row):
    text= row['template'] #Replace 'template' with the actual name of the column containing your text data
    verbs = []
    
    tokens = nltk.word_tokenize(text)
    tagged = nltk.pos_tag(tokens)
    verbs = [word.lower() for word, pos in tagged if (pos == 'VB' or pos == 'VBD' or pos == 'VBG' or pos == 'VBN' or pos == 'VBP' or pos == 'VBZ')and (not word.isnumeric())]
    return verbs

def add_nouns_verb_column(pool):
    pool['nouns'] = pool.apply(extract_nouns, axis=1)
    pool['verbs'] = pool.apply(extract_verbs, axis=1)

# %%
import sys
sys.argv = ['play.py', 'labels/train.json',  'labels/validation.json']

pool = read_jsons()

add_nouns_verb_column(pool)
pool

# %%
# Extract unique words from the 'text' column
unique_words = set(word for row in pool['nouns'] for word in row)

# Convert the set of unique words to a list if needed
unique_words_list = sorted(list(unique_words))

print(unique_words_list)
print(len(unique_words_list))
# Out:
# ['a-tshirt', 'a/c', 'aa', 'ab', 'abacus', 'abb', 'abby', 'abinder', 'abook', 'absorbent', 'absorber', 'ac', 'acake', 'accelarator', 'accelerator', 'accesories', 'access', 'accessoire', 'accessory', 'accumulator', 'acerola', 'acetaminophen', 'acetone', 'achaar', 'acorn', 'action', 'activation', 'activator', 'activia', 'ad', 'adapter', 'adaptor', 'adata', 'addepter', 'adhesive', 'adjuster', 'adopter', 'adoptor', 'adsl', 'adult', 'advent', 'advertisement', 'advertising', 'advertisment', 'advil', 'advisement', 'aeroplane', 'aerosal', 'aerosol', 'aerrings', 'aftershave', 'agarbathi', 'agarbathy', 'agarbatti', 'agarpathi', 'agenda', 'agent', 'agitator', 'ahoe', 'aid', 'aide', 'aiirbud', 'aim', 'aiphone', 'air', 'air-plane', 'aircondition', 'airconditioner', 'aircraft', 'airfreshner', 'airgun', 'airplane', 'airpod', 'airpods', 'airpump', 'airscrew', 'airspray', 'ajax', 'ajinomoto', 'aknife', 'alamara', 'alamera', 'alaram', 'alarm', 'album', 'alchol', 'alcohol', 'aldrop', 'ale', 'alebrije', 'aligator', 'alkaline', 'alligator', 'allout', 'alluminum', 'allumunium', 'almara', 'almera', 'almirah', 'almond', 'aloe', 'alovera', 'alpenliebe', 'alphabet', 'altimeter', 'altoids', 'alumini', 'aluminium', 'aluminum', 'amala', 'ambarla', 'ambulance', 'amethyst', 'amla', 'amongst', 'amp', 'amplifier', 'amrutanjan', 'amusement', 'analog', 'analogue', 'anbesol', 'anchor', 'android', 'angel', 'angle', 'angler', 'angrybird', 'animal', 'aniseed', 'anklet', 'anothe', 'ant', 'antacid', 'antena', 'antenas', 'antenna', 'anti', 'anti-scratch', 'anti-stapler', 'antiperspirant', 'antique', 'antistress', 'antler', 'anvil', 'aoutlet', 'ap', 'apartment', 'apparatus', 'apple', 'applesauce', 'appliance', 'appointment', 'appple', 'apricot', 'aqua', 'aquaphor', 'aquarium', 'ar', 'arby', 'area', 'arecanut', 'areosol', 'areplane', 'arm', 'armadillo', 'armature', 'armchair', 'armrest', 'army', 'arnament', 'arnica', 'aroma', 'aroplane', 'arosaul', 'arrangement', 'arrow', 'art', 'arthur', 'article', 'artiffacts', 'asafoetida', 'ash', 'ash-try', 'ashoe', 'ashtray', 'ashtrey', 'asparagus', 'aspirator', 'aspirin', 'assembly', 'aste', 'astor', 'astray', 'atention', 'athe', 'atm', 'atomizer', 'atta', 'attachment', 'attar', 'attepter', 'audi', 'audio', 'auditorium', 'aun', 'auto', 'automon', 'autorickshaw', 'autoriksha', 'aux', 'auyama', 'avacado', 'avenue', 'avocado', 'avocato', 'avr', 'award', 'awesimbook', 'axe', 'axel', 'ayebrow', 'ayeliner', 'b', 'bab', 'babana', 'bablet', 'baby', 'babypowder', 'bac', 'bacelet', 'back', 'backbag', 'backcase', 'backcover', 'backdoor', 'background', 'backlignt', 'backpack', 'backrest', 'backyard', 'bacon', 'bacteria', 'bacterium', 'badam', 'badge', 'badham', 'badhams', 'badminton', 'baf', 'bag', 'bagback', 'bagbox', 'baggage', 'baggie', 'bagpack', 'bailer', 'baisin', 'bajji', 'bakeware', 'baking', 'bakset', 'balaji', 'balance', 'balcony', 'bald', 'ball', 'ballast', 'ballon', 'ballone', 'balloon', 'ballpen', 'ballpoint', 'balm', 'baloon', 'baloons', 'balpoint', 'balsam', 'bam', 'bamboo', 'banaa', 'banan', 'banana', 'bananna', 'bancle', 'band', 'bandage', 'bandaid', 'bandaids', 'bandana', 'bandanna', 'bando', 'bangel', 'bangels', 'banggle', 'bangle', 'bango', 'banister', 'banjo', 'bank', 'bankbook', 'banknote', 'bannana', 'banner', 'bantage', 'bar', 'barb', 'barbecue', 'barbell', 'barbeque', 'barbie', 'barel', 'bark', 'barley', 'barner', 'barometer', 'barrage', 'barrel', 'barrette', 'barstool', 'barttery', 'bascket', 'base', 'baseball', 'basen', 'basil', 'basin', 'basket', 'basketball', 'baskin', 'baskt', 'bass', 'bastal', 'baster', 'bat', 'batch', 'bater', 'baterry', 'batery', 'bath', 'bath-tube', 'bathing', 'bathmat', 'bathrobe', 'bathroom', 'bathsoap', 'bathtowel', 'bathtub', 'batman', 'batmitton', 'batmobile', 'baton', 'battary', 'batter', 'batterie', 'batterry', 'battery', 'batterycell', 'battleship', 'battrey', 'batttery', 'bav', 'bawl', 'bay', 'bb', 'bbq', 'beach', 'bead', 'beaker', 'beam', 'bean', 'beanbag', 'beanie', 'beany', 'bear', ...
# 6232

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2

# %%
from spellchecker import SpellChecker

# Initialize the spell checker
spell = SpellChecker()

# Find potentially misspelled words
misspelled_nouns = spell.unknown(unique_words_list)

corrected_nouns = [spell.correction(word) for word in misspelled_nouns]

json_file_name = 'misspelled_nouns.json'
with open(json_file_name, 'w') as json_file:
    json.dump(list(misspelled_nouns), json_file)


json_file_name = 'corrected_nouns.json'
with open(json_file_name, 'w') as json_file:
    json.dump(list(corrected_nouns), json_file)

# %%
mpws = list(misspelled_words)

final_words = [corrected_words[mpws.index(word)] if word in misspelled_words and corrected_words[mpws.index(word)] is not None else word for word in unique_words_list]

# %%
misspelled_words
# Out:
# {'pancil',
#  'gaurd',
#  'exacto',
#  'autorickshaw',
#  'weedeater',
#  'sunchair',
#  'pecock',
#  'burse',
#  'bicyclist',
#  'glace',
#  'airscrew',
#  'evelope',
#  'aun',
#  'casettes',
#  'glases',
#  'gassstove',
#  'w',
#  'gomuthra',
#  'fevicol',
#  'botlle',
#  'injectio',
#  'sockdrawer',
#  'tinter',
#  'spinwheel',
#  'bhatter',
#  'toy-gun',
#  'hp',
#  'pag',
#  'stapples',
#  'chappels',
#  'goreng',
#  'mirchi',
#  'mixie',
#  'black-ink',
#  'deck-chair',
#  'shampooes',
#  'cigarettebox',
#  'disckgolf',
#  'hair-oil',
#  'screwcap',
#  'hairclipper',
#  'setsquare',
#  'scredriver',
#  'spects',
#  'keychian',
#  'oinment',
#  'godrej',
#  'scrole',
#  'protractor',
#  'duracell',
#  'lense',
#  'plaver',
#  'tostter',
#  'droor',
#  'bouguet',
#  'appple',
#  'calcualater',
#  'handtowels',
#  'lip-care',
#  'spillikin',
#  'batterry',
#  'wall/tarp',
#  'redchile',
#  'remotecontroller',
#  'couo',
#  'talucm',
#  'casette',
#  'christmastree',
#  'karpet',
#  'earjack',
#  'make-up',
#  'footbag',
#  'plag',
#  'drawar',
#  'gova',
#  'ush',
#  'alumini',
#  'kodam',
#  'hunder',
#  'kuerig',
#  'breacker',
#  'samsung',
#  'hedlight',
#  'aiirbud',
#  'toy2',
#  'camerabag',
#  'duppatta',
#  'éraser',
#  'fladhdisk',
#  'gummies',
#  'reeper',
#  'mainswitch',
#  'higlighter',
#  'parfume',
#  'shoebrush',
#  'battrey',
#  'fanta',
#  'deodarnt',
#  'tomatto',
#  'avr',
#  'wallete',
#  'subji',
#  'filp',
#  'abb',
#  'headhones',
#  'microfiber',
#  'brusher',
#  'fragance',
#  'handphones',
#  'agarpathi',
#  'wate',
#  'dupatta',
#  'frshener',
#  'spoonrest',
#  'ahoe',
#  'throwpillow',
#  'ironrad',
#  'flowerwase',
#  'flipflop',
#  'plastin',
#  'badam',
#  'tub/container',
#  'sapota',
#  'harddisk',
#  'paper-clip',
#  'wacth',
#  'ambarla',
#  'geomentry',
#  'streem',
#  'vrchair',
#  'flipcover',
#  'rubberband',
#  'mainboard',
#  'salompas',
#  'refridgerator',
#  'junkfood',
#  'corton',
#  'skycraper',
#  'dr.',
#  'sisplay',
#  'bottlle',
#  'coton',
#  'nechlas',
#  'cardboart',
#  'dishdrainer',
#  'saori',
#  'piug',
#  'sheild',
#  'bindes',
#  'groundnut',
#  'accelarator',
#  'riksh',
#  't-shir',
#  'solai',
#  'sopa',
#  'limonade',
#  'computermaus',
#  'white-cap',
#  'partenon',
#  'candlewarmer',
#  'sitout',
#  'jarlid',
#  'electricbox',
#  'conection',
#  'cardstock',
#  'hamer',
#  'sweetbox',
#  'flate',
#  'menas',
#  'spraypaint',
#  'squissy',
#  'luffy',
#  'photot',
#  'meganthi',
#  'jicama',
#  'patato',
#  'ointment-box',
#  'spones',
#  'merci-packung',
#  'libra',
#  'ricw',
#  'riksha',
#  'wter',
#  'glassholder',
#  'wardrope',
#  'bilimbi',
#  'piggybank',
#  'bando',
#  'worktop',
#  'sd',
#  'footweer',
#  'neckless',
#  'e-reader',
#  'extinquisher',
#  'listner',
#  'deoderent',
#  'wesson',
#  'cigarrette',
#  'clcualator',
#  'meganti',
#  'sanitiser',
#  'thropy',
#  'chapathi',
#  'airpump',
#  'sunscren',
#  'ps3',
#  'klennex',
#  'jalousie',
#  'psp',
#  'baf',
#  'soay',
#  'peiscope',
#  'two-pin',
#  'stoll',
#  'mayonase',
#  'cahrger',
#  'tothpicks',
#  'attepter',
#  'touchpad',
#  'penci',
#  'pumb',
#  'giftpack',
#  'woodenbox',
#  'bricheta',
#  'vissel',
#  'coushion',
#  'watercontainer',
#  'jewell',
#  'keybord',
#  'buckel',
#  'timeturner',
#  'tissus',
#  'penholder',
#  'paratha',
#  'taperecorder',
#  'cream-case',
#  'otp',
#  'rexona',
#  'maraca',
#  'towel-holder',
#  'toiler',
#  'rubicks',
#  'teagarden',
#  'liquidator',
#  'moneyy',
#  'cd/dvd',
#  'tele-commander',
#  'areplane',
#  'hawai',
#  'aroplane',
#  'contajner',
#  'celphone',
#  'phant',
#  'rcb',
#  'alchol',
#  'hospots',
#  'itoken',
#  'guithar',
#  'almera',
#  'chewbacca',
#  'paciphier',
#  'chocolet',
#  'spirometer',
#  'birthdy',
#  'pliiow',
#  'e-class',
#  'lipstisck',
#  'pingani',
#  'scissorrs',
#  'swith',
#  'cardreader',
#  'casrol',
#  'boxex',
#  'nickles',
#  'magnet\\',
#  'clothclip',
#  'grator',
#  'wrag',
#  'jat',
#  'telkom',
#  'fenceweave',
#  'kercheif',
#  'gamepad',
#  'l-joint',
#  'reciver',
#  'cigarbutt',
#  'diaperbag',
#  'espadrille',
#  'brushh',
#  'accessoire',
#  'fevigum',
#  'stearo',
#  'freeduino',
#  'carabinier',
#  'cardbox',
#  'sofaset',
#  'ucp',
#  'ovel',
#  'leggins',
#  'quitar',
#  'post-it',
#  'sativum',
#  'colgate',
#  'cantle',
#  'sauare',
#  'setofcompasses',
#  'febreeze',
#  'drower',
#  'razon',
#  'nokia',
#  'handspinner',
#  'cigaret',
#  'eveready',
#  'keyset',
#  'sigaretes',
#  'brom',
#  'powerbotton',
#  'dongle',
#  'pickel',
#  'hairspraiy',
#  'schokolade',
#  'buttom',
#  'cuboid',
#  's',
#  'visil',
#  'liptint',
#  'taank',
#  'mixergrinder',
#  'tipex-maus',
#  'gasstove',
#  'extender',
#  'cello-tape',
#  'bodywash',
#  'mirro',
#  'bheem',
#  'hairbands',
#  'shakespear',
#  'handfan',
#  'comsle',
#  'spacula',
#  'qtips',
#  'cleanig',
#  'textsurfer',
#  'pendrives',
#  'bord',
#  'taly',
#  'ruber',
#  'keychains',
#  'iron-box',
#  'decimeter',
#  'hair-bands',
#  'biscut',
#  'multi-plug',
#  'modam',
#  'bulding',
#  'chappals',
#  'vinger',
#  'controll',
#  'autoriksha',
#  'rubber-sheet',
#  'legiyam',
#  'headfone',
#  'liom',
#  'comd',
#  'bookbag',
#  'dolk',
#  'stlaper',
#  'dr.pepper',
#  'naseberry',
#  'odonil',
#  'achaar',
#  'chocklate',
#  'furit',
#  'arecanut',
#  'polsh',
#  'stel',
#  'scrissor',
#  'discgolf',
#  'measurment',
#  'cutboard',
#  'notbook',
#  'stapiller',
#  'closs',
#  'toster',
#  'ashoe',
#  'connectot',
#  'drawyer',
#  'cryon',
#  'forget-me-not',
#  'postit',
#  'bandaids',
#  'telehphone',
#  'zipploc',
#  'sheed',
#  'mascata',
#  'foood',
#  'glsss',
#  'stabler',
#  'c',
#  'bluetooh',
#  'numberplate',
#  'antena',
#  'puzzler',
#  'piller',
#  'vessle',
#  'cosco',
#  'kikker',
#  'inkfiller',
#  'chockpiece',
#  'fruitshake',
#  'poloshirt',
#  'walllet',
#  'handhand',
#  'jcb',
#  'bathmat',
#  'nailcutte',
#  'budweiser',
#  'areosol',
#  'mastard',
#  'kolleg',
#  'ferrocerium',
#  'compaas',
#  'shoda',
#  'tetorch',
#  'kinife',
#  'pos-it',
#  'tape-roll',
#  'bottletop',
#  'perfum',
#  'flowervase',
#  'toothapste',
#  'suglass',
#  'gle',
#  'vapouriser',
#  'garnier',
#  'suger',
#  'airfreshner',
#  'sofa-set',
#  'barel',
#  'n',
#  'vapourb',
#  'jel',
#  'paperr',
#  'notizheft',
#  'r',
#  'raquet',
#  'eyehook',
#  'matress',
#  'disck',
#  'cigratte',
#  'pera',
#  'stufftoy',
#  'cigarstub',
#  'papercilp',
#  'avocato',
#  'd-link',
#  'plam',
#  'wrist-watch',
#  'hardrive',
#  'marbel',
#  'plastoc',
#  'starwars',
#  'ligher',
#  'otg',
#  'contaner',
#  'aircondition',
#  'crea',
#  'steker',
#  'k',
#  'pro-biker',
#  'callendar',
#  'toothstick',
#  'coir',
#  'beany',
#  'corer',
#  'glouse',
#  'post-il',
#  'flosser',
#  'madicines',
#  'cabage',
#  'dishtowel',
#  'mixer-jar',
#  'muram',
#  'ironbox',
#  'cilp',
#  'eliquid',
#  'fhoto',
#  'taschentücher',
#  'wallclock',
#  'tshirt',
#  'paperball',
#  'arby',
#  'cuo',
#  'boxa',
#  'karchief',
#  'cardvalidator',
#  'kadhakali',
#  'flexo',
#  'conatiner',
#  'moka',
#  'cabnet',
#  'koolaid',
#  'chifu',
#  'perrier',
#  'insole',
#  'pem',
#  'matxhboxes',
#  'gallar',
#  'abinder',
#  'evod',
#  'hairtie',
#  'sidewall',
#  'tootbrush',
#  'shor',
#  'playr',
#  'kircheif',
#  'blistex',
#  'toothpiks',
#  'rimmel',
#  'sculture',
#  'susages',
#  'squeege',
#  'creame',
#  'cobtainer',
#  'deodrannt',
#  'plastic-paper',
#  'saltshaker',
#  'rremote',
#  'parfum',
#  'moisteuriser',
#  'frying-pan',
#  'pastille',
#  'socket/outlet',
#  'soccerball',
#  'coca-cola',
#  'i.d',
#  'sabji',
#  'powerbutton',
#  'clothline',
#  'plugger',
#  'tibex',
#  'pricetag',
#  'airconditioner',
#  'jouice',
#  'eyeshadow',
#  'jwellry',
#  'startee',
#  'copo',
#  'laaptop',
#  'bajji',
#  'steelglass',
#  'invertor',
#  'lepidium',
#  'neckalce',
#  'rosmarus',
#  'monile',
#  'textsufer',
#  'sandwichera',
#  'wallframe',
#  'handwasher',
#  'melantonin',
#  'body-lotion',
#  'antenas',
#  'skilet',
#  'rokk',
#  'cutp',
#  'utensials',
#  'pinestraw',
#  'cheapel',
#  'tapeline',
#  'lamon',
#  'repelent',
#  'dhal',
#  'sellotape',
#  'backcase',
#  'etuie',
#  'cabinete',
#  'q-tip',
#  'suplement',
#  'cajuput',
#  'papper',
#  'beatle',
#  'boody',
#  'srikaya',
#  'botton',
#  'daimond',
#  'adoptor',
#  'multivamins',
#  'ledle',
#  'cruct',
#  'sriver',
#  'caprisun',
#  'beetrroot',
#  'fower',
#  'claculator',
#  'mircorwave',
#  'prenjak',
#  'shamppo',
#  'quqrters',
#  'ice-cream',
#  'peice',
#  'cutex',
#  'refrigrator',
#  'kork',
#  'chewingum',
#  'bottlecap',
#  'vr',
#  'gitar',
#  'toohbrush',
#  'bacelet',
#  'reciept',
#  'blueray',
#  '‘',
#  'choli',
#  'haidryer',
#  'pemcil',
#  'houseplant',
#  'naphthalene',
#  'metl',
#  'tablestopper',
#  'umbrela',
#  'spile',
#  'pc',
#  'plastic-cover',
#  'doorstopper',
#  'cofee',
#  'gamepieces',
#  'sponch',
#  'panch',
#  'scruber',
#  'pineaplle',
#  'videogsme',
#  'clothspin',
#  'clothpin',
#  'fishfood',
#  'laterate',
#  'telkomsel',
#  'chille',
#  'moile',
#  'babana',
#  'paperbox',
#  'potholder',
#  'stepper',
#  'take-out',
#  'cycas',
#  'kadhai',
#  'romote',
#  'peanutbutter',
#  'flacon',
#  'mirroe',
#  'multipocket',
#  'croton',
#  'cormac',
#  'nailcutter',
#  'snyders',
#  'ajax',
#  'amla',
#  'githar',
#  'newsaper',
#  'air-plane',
#  'plastic-container',
#  'sapi',
#  'taskpane',
#  'keurig',
#  'psck',
#  'parota',
#  'stamppad',
#  'teapowder',
#  'landphone',
#  'kays',
#  'waterpik',
#  'laddle',
#  'chlothes',
#  'facecream',
#  'netsetter',
#  'modge',
#  'scourer',
#  'fillter',
#  'sharpners',
#  'ploythene',
#  'tiffenbox',
#  'similer',
#  'glassball',
#  'spectalics',
#  'coozie',
#  'lb',
#  'alpenliebe',
#  'magaine',
#  'kichen',
#  'papet',
#  'methi',
#  'cofffee',
#  'rava',
#  'bose',
#  'stablizer',
#  'agarbathy',
#  'teethbrush',
#  'npaperote',
#  'tooyhpaste',
#  'kerala',
#  'macbook',
#  'meeter',
#  'usb/mouse',
#  'caculator',
#  'butine',
#  'graims',
#  'hairgel',
#  'smatphone',
#  'ganesha',
#  'chatgerlight',
#  'swicth',
#  'cuprisun',
#  'wardobe',
#  'ignitor',
#  'handbrush',
#  'vinager',
#  'darwaza',
#  'woodbowl',
#  'breakfeast',
#  'firealarm',
#  'notecard',
#  'pendrive',
#  'listerine',
#  'fingernail.com',
#  'srewdriver',
#  'scaler',
#  'oli',
#  'jell-o',
#  'diya',
#  'fall\\',
#  'cest',
#  'earplug',
#  'batterie',
#  'cc',
#  'ornithopod',
#  'saltern',
#  'shoerack',
#  'mp4',
#  'verifier',
#  'tedy',
#  'cottonbud',
#  'thoothbrush',
#  'tropicana',
#  'teapoy',
#  'complan',
#  'giftbox',
#  'oilbottle',
#  'coffemix',
#  't-shirt',
#  'orangepeel',
#  'oscillograph',
#  'rubber/eraser',
#  'altoids',
#  'paperbag',
#  'rollerskate',
#  'ayebrow',
#  'ice-tray',
#  'rubber-band',
#  'capsicum',
#  'papepr',
#  'lifebouy',
#  'singlet',
#  'streetsign',
#  'tupper',
#  'heansead',
#  'bootsw',
#  'keybound',
#  'nailpolosh',
#  'pen/pencil',
#  'cion',
#  'ramekin',
#  'daugh',
#  'bascket',
#  'phonecell',
#  'haxo',
#  'raisens',
#  'wallett',
#  'niddle',
#  'rootcrop',
#  'playdough',
#  'stell',
#  'moprod',
#  'meltykiss',
#  'tabala',
#  'toungh',
#  'sissor',
#  'badhams',
#  'bitterguard',
#  'crocker',
#  'hairsprays',
#  'plastic-socket',
#  'spidol',
#  'powdee',
#  'degresser',
#  'footcare',
#  'cleese',
#  'plastic-bag',
#  'aknife',
#  'gaterade',
#  'pallete',
#  'referigerator',
#  'calci',
#  'somethinf',
#  'biskit',
#  'dumbells',
#  'ligther',
#  'boc',
#  'chackpice',
#  'knief',
#  'iid',
#  'dusudt',
#  'mt',
#  'souce',
#  'medicin',
#  'perfune',
#  'subglasses',
#  'carrousel',
#  'ballpen',
#  'strolley',
#  'eyedrop',
#  'sandels',
#  'noddle',
#  'bokey',
#  'fone',
#  'telcom',
#  'iotion',
#  'spacebar',
#  'shashe',
#  'laminator',
#  'dall',
#  'handpurse',
#  'hairbow',
#  'surimi',
#  'bakset',
#  'watter',
#  'chappel',
#  'rool',
#  'cocount',
#  'footswitch',
#  'sculp',
#  'swithboard',
#  'toy1',
#  'cabinate',
#  'monopod',
#  'aerosal',
#  'bootle',
#  'pastiles',
#  'necklase',
#  'clothclips',
#  'mudguard',
#  'battary',
#  'vasaline',
#  'auyama',
#  'frridge',
#  'dishwash',
#  'jwellery',
#  'pipecleaner',
#  'lipliner',
#  'glassbird',
#  'indofood',
#  'jbl',
#  'tablr',
#  'tp',
#  'popcord',
#  'sfety',
#  'tissu',
#  'suji',
#  'ladel',
#  'connecter',
#  'watee',
#  'hygrometer',
#  'plugpoint',
#  'scatch',
#  'sand/',
#  'laddies-finger',
#  'veet',
#  'suncreen',
#  'tanticle',
#  'comal',
#  'tumler',
#  'mustrd',
#  'celeadoscope',
#  'braclet',
#  'clipnoard',
#  'inkpen',
#  'comicbook',
#  'play-doh',
#  'rular',
#  'crums',
#  'sccisors',
#  'spaner',
#  'tin-foil',
#  'extintor',
#  'eraeser',
#  'stevenson',
#  'bero',
#  'coffeecup',
#  'porridgeja',
#  'bluray',
#  'softdrinks',
#  'cummin',
#  'waterfloss',
#  'earmuff',
#  'bittle',
#  'phill',
#  'contaier',
#  'woofer',
#  'icard',
#  'sambrani',
#  'batmitton',
#  'bedcover',
#  'shapner',
#  'edc',
#  'tetrapack',
#  'cadbury',
#  'sunglss',
#  'birck',
#  'advertisment',
#  'healthdrink',
#  'puff-box',
#  'speedlite',
#  'junggling',
#  'sandbax',
#  'wc',
#  'а',
#  'basen',
#  'hairclips',
#  'keledeoscope',
#  'arosaul',
#  'digicam',
#  'puple',
#  'masjid',
#  'attar',
#  'candelholder',
#  'beetween',
#  'notenook',
#  'pushpin',
#  'slothespin',
#  'wetwipe',
#  'wash-basin',
#  'markes',
#  'hotpack',
#  'stylo',
#  'calculater',
#  'pumpink',
#  'canistet',
#  'usbc',
#  'knifie',
#  'bole',
#  'v8',
#  'ricecooker',
#  'moniter',
#  'keurrig',
#  'bottel',
#  'keyhanger',
#  'firelog',
#  'batmobile',
#  'sibe',
#  'penstand',
#  'texbook',
#  'davidson',
#  'hearphone',
#  'remot',
#  'waiste',
#  'oilment',
#  'pappya',
#  'cofffe-jar',
#  'flashdisk',
#  'shuffler',
#  'tulsi',
#  'mixi',
#  'knifs',
#  'botte',
#  'martch',
#  'rist',
#  'heaphone',
#  'plectrum',
#  'oragami',
#  'rabit',
#  'moneybox',
#  'tinbox',
#  'freashner',
#  'stuufed',
#  'kontak',
#  'lcd',
#  'freeezer',
#  'ticso',
#  'electabuzz',
#  'toiletcabin',
#  'callender',
#  'hardboard',
#  'punnet',
#  'jumpdrive',
#  'dimsum',
#  'washclothe',
#  'jujubi',
#  'napking',
#  'siccors',
#  'ajinomoto',
#  'waterbotle',
#  ...}

# %%
corrected_words
# Out:
# ['pencil',
#  'guard',
#  'exact',
#  None,
#  None,
#  'unchain',
#  'peacock',
#  'nurse',
#  'bicycles',
#  'place',
#  None,
#  'envelope',
#  'an',
#  'cassettes',
#  'glass',
#  None,
#  'i',
#  None,
#  None,
#  'bottle',
#  'injection',
#  None,
#  'winter',
#  'pinwheel',
#  'chatter',
#  None,
#  'he',
#  'pay',
#  'staples',
#  'chapels',
#  'goring',
#  'michi',
#  'pixie',
#  'blacking',
#  None,
#  'shampoos',
#  None,
#  None,
#  None,
#  'screwup',
#  None,
#  None,
#  'screwdriver',
#  'aspects',
#  'keychain',
#  'ointment',
#  'gore',
#  'scroll',
#  'protector',
#  'purcell',
#  'sense',
#  'player',
#  'totter',
#  'door',
#  'bouquet',
#  'apple',
#  'calculate',
#  None,
#  None,
#  None,
#  'battery',
#  None,
#  None,
#  None,
#  'coup',
#  'talcum',
#  'cassette',
#  'christmastime',
#  'carpet',
#  'carjack',
#  'makeup',
#  'football',
#  'play',
#  'drawer',
#  'nova',
#  'us',
#  'alumni',
#  'kadam',
#  'under',
#  'keri',
#  'breaker',
#  'sassing',
#  'headlight',
#  None,
#  'toy',
#  'cameraman',
#  None,
#  'eraser',
#  None,
#  'dummies',
#  'deeper',
#  None,
#  'highlighter',
#  'perfume',
#  'sagebrush',
#  'battery',
#  'santa',
#  'deodorant',
#  'tomato',
#  'air',
#  'wallet',
#  'submit',
#  'film',
#  'abs',
#  'headphones',
#  None,
#  'brushed',
#  'fragrance',
#  'handphone',
#  None,
#  'hate',
#  'datta',
#  'freshener',
#  'poorest',
#  'shoe',
#  None,
#  'ironed',
#  'lowercase',
#  None,
#  'plastic',
#  'madam',
#  None,
#  'spot',
#  None,
#  'paperclip',
#  'watch',
#  'marla',
#  'geometry',
#  'street',
#  'chair',
#  None,
#  None,
#  'inboard',
#  None,
#  'refrigerator',
#  None,
#  'cotton',
#  'skyscraper',
#  'dry',
#  'display',
#  'bottle',
#  'cotton',
#  'nicholas',
#  'cardboard',
#  None,
#  'sari',
#  'pig',
#  'shield',
#  'binds',
#  None,
#  'accelerator',
#  'rish',
#  'tushie',
#  'solar',
#  'soap',
#  'lemonade',
#  None,
#  None,
#  None,
#  None,
#  'stout',
#  'valid',
#  None,
#  'connection',
#  'yardstick',
#  'hammer',
#  'sweatbox',
#  'late',
#  'means',
#  None,
#  'squishy',
#  'fluffy',
#  'photo',
#  None,
#  'cicada',
#  'potato',
#  None,
#  'stones',
#  None,
#  'lira',
#  'rich',
#  'rickshaw',
#  'water',
#  None,
#  'wardrobe',
#  None,
#  'piggyback',
#  'band',
#  'workshop',
#  'so',
#  'footwear',
#  'reckless',
#  'reader',
#  'extinguisher',
#  'listener',
#  'deodorant',
#  'lesson',
#  'cigarette',
#  'calculator',
#  'meant',
#  'sanitizer',
#  'throw',
#  None,
#  None,
#  'sunscreen',
#  'psi',
#  'kleenex',
#  'jealousies',
#  'pop',
#  'bad',
#  'say',
#  'periscope',
#  None,
#  'still',
#  'mayonnaise',
#  'charger',
#  'toothpicks',
#  'attempted',
#  'touched',
#  'pencil',
#  'dumb',
#  None,
#  None,
#  None,
#  'vessel',
#  'cushion',
#  None,
#  'jewels',
#  'keyboard',
#  'bucket',
#  None,
#  'tissue',
#  'beholder',
#  'parathas',
#  None,
#  None,
#  'top',
#  'recon',
#  'maracas',
#  None,
#  'toilet',
#  'bricks',
#  None,
#  'liquidate',
#  'money',
#  None,
#  None,
#  'replace',
#  'hawaii',
#  'aeroplane',
#  'container',
#  'cellphone',
#  'plant',
#  'rob',
#  'alcohol',
#  'hotspots',
#  'token',
#  'guitar',
#  'camera',
#  None,
#  'pacifier',
#  'chocolat',
#  None,
#  'birthday',
#  'pillow',
#  'class',
#  'lipstick',
#  'pinging',
#  'scissors',
#  'with',
#  None,
#  'carol',
#  'boxes',
#  'pickles',
#  'magnet',
#  None,
#  'gator',
#  'drag',
#  'at',
#  'seldom',
#  None,
#  'kerchief',
#  'gamed',
#  'joint',
#  'recover',
#  None,
#  None,
#  None,
#  'brush',
#  'accessory',
#  None,
#  'start',
#  None,
#  'carabinieri',
#  'carbon',
#  'offset',
#  'up',
#  'over',
#  'leggings',
#  'guitar',
#  'posit',
#  'latinum',
#  'collate',
#  'castle',
#  'square',
#  None,
#  'freeze',
#  'drawer',
#  'razor',
#  'nova',
#  None,
#  'cigarette',
#  'everyday',
#  'keyser',
#  'cigarettes',
#  'from',
#  None,
#  'dangle',
#  'picked',
#  'hairspray',
#  None,
#  'bottom',
#  'couid',
#  'i',
#  'visit',
#  'lifting',
#  'thank',
#  None,
#  None,
#  None,
#  'extended',
#  None,
#  None,
#  'mirror',
#  'beem',
#  'fairbanks',
#  'shakespeare',
#  'handful',
#  'come',
#  'spatula',
#  'tips',
#  'cleaning',
#  None,
#  'endives',
#  'word',
#  'talk',
#  'rubber',
#  'keychain',
#  None,
#  'perimeter',
#  None,
#  'biscuit',
#  None,
#  'madam',
#  'building',
#  'chapels',
#  'finger',
#  'control',
#  None,
#  None,
#  None,
#  'headline',
#  'lion',
#  'come',
#  'booking',
#  'doll',
#  'stalker',
#  None,
#  'raspberry',
#  'donit',
#  'chair',
#  'chocolate',
#  'fruit',
#  'recant',
#  'polish',
#  'step',
#  'scissor',
#  None,
#  'measurement',
#  'cupboard',
#  'notebook',
#  'stapler',
#  'close',
#  'foster',
#  'shoe',
#  'connector',
#  'drawer',
#  'cryo',
#  None,
#  'posit',
#  'bandaid',
#  'telephone',
#  'ziploc',
#  "she'd",
#  'mascara',
#  'food',
#  'glass',
#  'stable',
#  'i',
#  'bluetooth',
#  None,
#  'antenna',
#  'puzzle',
#  'killer',
#  'vessel',
#  'coco',
#  'kicker',
#  None,
#  None,
#  'fruitcake',
#  None,
#  'wallet',
#  'handheld',
#  'job',
#  'batman',
#  None,
#  None,
#  'aerosol',
#  'bastard',
#  'killed',
#  None,
#  'compass',
#  'soda',
#  'torch',
#  'knife',
#  'posit',
#  None,
#  None,
#  'perfume',
#  'lowercase',
#  'toothpaste',
#  'sunglass',
#  'le',
#  'vaporised',
#  'garner',
#  'super',
#  None,
#  None,
#  'barely',
#  'i',
#  'vapour',
#  'jet',
#  'paper',
#  None,
#  'i',
#  'raquel',
#  None,
#  'mattress',
#  'dick',
#  'cigarette',
#  'per',
#  'stuffto',
#  None,
#  'paperclip',
#  'avocado',
#  'drink',
#  'play',
#  'wristwatch',
#  'arrive',
#  'marble',
#  'plastic',
#  'starters',
#  'higher',
#  'ot',
#  'container',
#  None,
#  'area',
#  'steer',
#  'i',
#  None,
#  'calendar',
#  'toothpick',
#  'coin',
#  'beans',
#  'cover',
#  'blouse',
#  'postal',
#  'flossed',
#  'medicines',
#  'cabbage',
#  None,
#  None,
#  'mural',
#  'ironborn',
#  'clip',
#  'liquid',
#  'photo',
#  None,
#  None,
#  'shirt',
#  'paperback',
#  'army',
#  'cut',
#  'box',
#  'kerchief',
#  None,
#  None,
#  'flex',
#  'container',
#  'mona',
#  'cabinet',
#  None,
#  'shifu',
#  'terrier',
#  'insoles',
#  'per',
#  'matchboxes',
#  'gellar',
#  'binder',
#  'evo',
#  'hairline',
#  'sidewalk',
#  'toothbrush',
#  'show',
#  'play',
#  'kerchief',
#  'blister',
#  'toothpicks',
#  'rimmed',
#  'culture',
#  'sausages',
#  'squeeze',
#  'create',
#  'container',
#  'deodorant',
#  None,
#  None,
#  'remote',
#  'perfume',
#  'moisturiser',
#  None,
#  'bastille',
#  None,
#  None,
#  None,
#  "i'd",
#  'rabbi',
#  None,
#  'clothing',
#  'plugged',
#  'ibex',
#  None,
#  None,
#  'juice',
#  None,
#  'jewelry',
#  'started',
#  'cops',
#  'laptop',
#  'hajji',
#  None,
#  'inventor',
#  None,
#  'necklace',
#  None,
#  'mobile',
#  None,
#  'sandwiches',
#  None,
#  None,
#  'melatonin',
#  None,
#  'antennas',
#  'skillet',
#  'rock',
#  'cut',
#  'utensils',
#  None,
#  'cheaper',
#  'timeline',
#  'lemon',
#  'repellent',
#  'deal',
#  None,
#  'bookcase',
#  'tie',
#  'cabinet',
#  'tip',
#  'supplement',
#  None,
#  'paper',
#  'beetle',
#  'body',
#  None,
#  'bottom',
#  'diamond',
#  'adaptor',
#  None,
#  'ledge',
#  'crust',
#  'river',
#  None,
#  'beetroot',
#  'power',
#  'calculator',
#  'microwave',
#  None,
#  'shampoo',
#  'quarters',
#  'icecream',
#  'piece',
#  'cute',
#  'refrigerator',
#  'work',
#  'chewing',
#  None,
#  'or',
#  'guitar',
#  'toothbrush',
#  'bracelet',
#  'receipt',
#  'blurry',
#  'i',
#  'chili',
#  'hairdryer',
#  'pencil',
#  None,
#  None,
#  'met',
#  None,
#  'umbrella',
#  'smile',
#  'pa',
#  None,
#  None,
#  'coffee',
#  None,
#  'ponch',
#  'punch',
#  'scrubber',
#  'pineapple',
#  'videogame',
#  'clothespin',
#  'clothing',
#  'fishhook',
#  'literate',
#  None,
#  'chill',
#  'mile',
#  'banana',
#  'paperboy',
#  'potholes',
#  'stepped',
#  'takeout',
#  'cycle',
#  'radha',
#  'remote',
#  None,
#  'falcon',
#  'mirror',
#  None,
#  'proton',
#  'normal',
#  None,
#  'snyder',
#  'ajar',
#  'alma',
#  'either',
#  'newspaper',
#  'airplane',
#  None,
#  'sap',
#  None,
#  'keri',
#  'pick',
#  'part',
#  'stamped',
#  None,
#  'handphone',
#  'says',
#  None,
#  'saddle',
#  'clothes',
#  'icecream',
#  'newsletter',
#  'lodge',
#  'scoured',
#  'filter',
#  'sharpness',
#  'polythene',
#  None,
#  'similar',
#  None,
#  None,
#  'cookie',
#  'la',
#  None,
#  'magazine',
#  'kitchen',
#  'paper',
#  'meth',
#  'coffee',
#  'lava',
#  'lose',
#  'stabilizer',
#  None,
#  'toothbrush',
#  None,
#  'toothpaste',
#  'herald',
#  'facebook',
#  'meter',
#  None,
#  'calculator',
#  'butane',
#  'grams',
#  'haired',
#  'smartphone',
#  'gangsta',
#  None,
#  'switch',
#  None,
#  'wardrobe',
#  'igniter',
#  'hairbrush',
#  'finger',
#  None,
#  'woodrow',
#  'breakfast',
#  'firearm',
#  'notepad',
#  'pensive',
#  'listening',
#  None,
#  'screwdriver',
#  'scale',
#  'old',
#  'jello',
#  'diva',
#  'fall',
#  'best',
#  'earplugs',
#  'batteries',
#  'ca',
#  None,
#  'pattern',
#  'shoelace',
#  'my',
#  'verified',
#  'tidy',
#  'cottoned',
#  'toothbrush',
#  'tropical',
#  'teapot',
#  'complain',
#  None,
#  None,
#  None,
#  'shirt',
#  None,
#  None,
#  None,
#  'avoids',
#  'paperback',
#  None,
#  'eyebrow',
#  None,
#  None,
#  'caesium',
#  'paper',
#  'lifeboat',
#  'single',
#  None,
#  'upper',
#  None,
#  'boots',
#  'keyboard',
#  None,
#  None,
#  'con',
#  'ramen',
#  'laugh',
#  'basket',
#  'phonecall',
#  'halo',
#  'raises',
#  'wallet',
#  'middle',
#  'outcrop',
#  None,
#  'tell',
#  'mood',
#  None,
#  'tabula',
#  'tough',
#  'scissor',
#  'badass',
#  None,
#  'cracker',
#  'hairspray',
#  None,
#  'spoil',
#  'powder',
#  'depressed',
#  'footage',
#  'cheese',
#  None,
#  'knife',
#  'gatorade',
#  'pallet',
#  'refrigerator',
#  'cali',
#  'something',
#  'visit',
#  'dumbbells',
#  'lighter',
#  'boy',
#  None,
#  'knife',
#  'did',
#  'dust',
#  'it',
#  'source',
#  'medicine',
#  'perfume',
#  'sunglasses',
#  'carousel',
#  'bullpen',
#  'trolley',
#  'eyedrops',
#  'sandals',
#  'noodle',
#  'bogey',
#  'one',
#  'telecom',
#  'motion',
#  'spaceman',
#  'shashi',
#  'laminated',
#  'all',
#  None,
#  'rainbow',
#  'shrimp',
#  'basket',
#  'matter',
#  'chapel',
#  'room',
#  'coconut',
#  None,
#  'scalp',
#  'switchboard',
#  'toy',
#  'cabinet',
#  'monopoly',
#  'aerosol',
#  'bottle',
#  'pasties',
#  'necklace',
#  None,
#  None,
#  'battery',
#  'vaseline',
#  'adama',
#  'fridge',
#  'dishwasher',
#  'jewellery',
#  None,
#  'airliner',
#  None,
#  None,
#  'jal',
#  'table',
#  'to',
#  'popcorn',
#  'safety',
#  'tissue',
#  'suki',
#  'label',
#  'connected',
#  'water',
#  None,
#  None,
#  'catch',
#  'sand',
#  None,
#  'meet',
#  'sunscreen',
#  'article',
#  'coal',
#  'tumbler',
#  'mustard',
#  None,
#  'bracelet',
#  'clipboard',
#  'inked',
#  None,
#  None,
#  'ruler',
#  'drums',
#  'scissors',
#  'spanner',
#  'tinfoil',
#  'extensor',
#  'eraser',
#  'stevens',
#  'hero',
#  None,
#  'porridge',
#  'blurry',
#  None,
#  'cumin',
#  'waterless',
#  'earmuffs',
#  'little',
#  'hill',
#  'container',
#  'roofer',
#  'card',
#  'samurai',
#  'badminton',
#  'recover',
#  'shaper',
#  'ed',
#  None,
#  'asbury',
#  'sunglass',
#  'brick',
#  'advertisement',
#  None,
#  None,
#  None,
#  'juggling',
#  'sandbox',
#  'we',
#  'i',
#  'based',
#  None,
#  None,
#  'arousal',
#  'digital',
#  'purple',
#  'majid',
#  'altar',
#  None,
#  'between',
#  'notebook',
#  'pushing',
#  'clothespin',
#  'wetware',
#  'washbasin',
#  'makes',
#  'jetpack',
#  'style',
#  'calculate',
#  'pumping',
#  'canister',
#  'usc',
#  'knife',
#  'hole',
#  've',
#  None,
#  'monster',
#  None,
#  'bottle',
#  None,
#  'firebug',
#  None,
#  'side',
#  None,
#  'textbook',
#  None,
#  'headphone',
#  'remote',
#  'waste',
#  'ailment',
#  'pappy',
#  None,
#  None,
#  'shuffle',
#  'tulsa',
#  'mix',
#  'knife',
#  'bottle',
#  'match',
#  'rest',
#  'headphone',
#  'spectrum',
#  'origami',
#  'habit',
#  'moneyto',
#  'inbox',
#  'fresher',
#  'stuffed',
#  'kota',
#  'led',
#  'freezer',
#  'tics',
#  None,
#  None,
#  'calender',
#  'cardboard',
#  'planet',
#  None,
#  'dims',
#  'washcloth',
#  'jujube',
#  'napkin',
#  'sectors',
#  None,
#  'waterhole',
#  ...]

# %%
pool_filtered = pool
pool_filtered['verb+noun'] = pool_filtered['verbs'].str[0] + ' ' + pool_filtered['nouns'].str[0]
pool_filtered['verb+noun']
# Out:
# 0              holding potato
# 1         spreading margarine
# 2                 putting pen
# 3              lifting bottle
# 4                holding bulb
#                  ...
# 193685             moving car
# 193686      closing freshmint
# 193687        unfolding shirt
# 193688            moving glas
# 193689        falling plastic
# Name: verb+noun, Length: 193690, dtype: object

# %%
# stats info on how many rows have the same verb+noun for each label, in ascending order
pool_filtered.groupby('label')['verb+noun'].value_counts().sort_values()

# %%
# remove all the rouns in which the amount of rows with the same verb+noun is less than 5
pool_filtered = pool_filtered.groupby('label').filter(lambda x: len(x) > 5)

# %%
# pool['nouns'].str.contains(r'^-?\d+(?:\.\d+)?$').any()
# pool[pool['nouns'].str.len() < 3]
# pool['nouns'].str.len()
# pool[pool['nouns'].apply(lambda x: any(len(i) < 2 for i in x))]
# pool[~pool['nouns'].astype(bool)]
# Out:
#             id                                        label
# 2       100904                     putting pen on a surface  \
# 104     200377                      pretending to throw pen
# 106     170861                     putting pen on a surface
# 182     139538                            squeezing eatable
# 247     202794                  bending pen until it breaks
# ...        ...                                          ...
# 193524   39756               pushing pen from right to left
# 193528   32750        letting pen roll along a flat surface
# 193560   65088                      putting pen next to pen
# 193633  112050                                opening pouch
# 193643  149405  throwing pen in the air and letting it fall
#
#                                                  template placeholders nouns
# 2                        Putting [something] on a surface        [pen]    []  \
# 104                       Pretending to throw [something]        [pen]    []
# 106                      Putting [something] on a surface        [pen]    []
# 182                                 Squeezing [something]    [eatable]    []
# 247                   Bending [something] until it breaks        [pen]    []
# ...                                                   ...          ...   ...
# 193524             Pushing [something] from right to left        [pen]    []
# 193528      Letting [something] roll along a flat surface        [pen]    []
# 193560            Putting [something] next to [something]   [pen, pen]    []
# 193633                                Opening [something]      [pouch]    []
# 193643  Throwing [something] in the air and letting it...        [pen]    []
#
#                             verbs
# 2                       [putting]
# 104           [pretending, throw]
# 106                     [putting]
# 182                   [squeezing]
# 247             [bending, breaks]
# ...                           ...
# 193524            [pushing, left]
# 193528                  [letting]
# 193560               [putting, []
# 193633                  [opening]
# 193643  [throwing, letting, fall]
#
# [3325 rows x 6 columns]

# %%
def unique_templates(pool):
    """
    Returns a list of unique strings in the 'template' column of a Pandas DataFrame.
    """
    unique = pool['template'].unique()
    return list(unique)

uni_template = unique_templates(pool)
print('size uni_templates: ', len(uni_template))
uni_template
# Out:
# size uni_templates:  174
# ['Holding [something] next to [something]',
#  'Spreading [something] onto [something]',
#  'Putting [something] on a surface',
#  'Lifting up one end of [something], then letting it drop down',
#  'Holding [something]',
#  'Pushing [something] from right to left',
#  'Spilling [something] onto [something]',
#  'Pushing [something] so that it slightly moves',
#  'Moving [something] across a surface until it falls down',
#  'Folding [something]',
#  'Taking [one of many similar things on the table]',
#  'Pretending to turn [something] upside down',
#  'Pretending to take [something] from [somewhere]',
#  'Moving [something] up',
#  'Twisting (wringing) [something] wet until water comes out',
#  'Twisting [something]',
#  'Taking [something] out of [something]',
#  'Dropping [something] in front of [something]',
#  'Throwing [something] in the air and letting it fall',
#  'Lifting up one end of [something] without letting it drop down',
#  'Moving [something] towards the camera',
#  'Showing that [something] is empty',
#  'Dropping [something] behind [something]',
#  'Throwing [something] against [something]',
#  'Holding [something] over [something]',
#  'Moving [something] and [something] closer to each other',
#  'Pushing [something] so it spins',
#  'Covering [something] with [something]',
#  'Putting [something] into [something]',
#  'Showing that [something] is inside [something]',
#  'Throwing [something]',
#  'Pulling [something] from right to left',
#  'Tipping [something] over',
#  'Poking a stack of [something] without the stack collapsing',
#  'Letting [something] roll along a flat surface',
#  'Showing [something] behind [something]',
#  'Dropping [something] onto [something]',
#  'Throwing [something] in the air and catching it',
#  'Squeezing [something]',
#  'Pushing [something] off of [something]',
#  'Putting [something] upright on the table',
#  'Failing to put [something] into [something] because [something] does not fit',
#  'Putting [something] onto [something else that cannot support it] so it falls down',
#  'Moving [something] down',
#  'Hitting [something] with [something]',
#  'Putting [something] on the edge of [something] so it is not supported and falls down',
#  'Moving [something] across a surface without it falling down',
#  'Putting [something] and [something] on the table',
#  'Touching (without moving) [part] of [something]',
#  'Pretending to be tearing [something that is not tearable]',
#  'Putting [something] in front of [something]',
#  '[Something] falling like a rock',
#  'Holding [something] in front of [something]',
#  'Putting [something] underneath [something]',
#  'Pretending to put [something] on a surface',
#  'Pulling [something] out of [something]',
#  'Moving [something] away from [something]',
#  'Tilting [something] with [something] on it until it falls off',
#  'Moving [something] away from the camera',
#  'Pushing [something] from left to right',
#  'Moving [something] closer to [something]',
#  'Tearing [something] into two pieces',
#  '[Something] falling like a feather or paper',
#  'Showing [something] next to [something]',
#  'Scooping [something] up with [something]',
#  'Putting [something] onto [something]',
#  'Lifting [something] up completely, then letting it drop down',
#  'Putting [something similar to other things that are already on the table]',
#  'Pretending to throw [something]',
#  'Lifting [something] with [something] on it',
#  'Sprinkling [something] onto [something]',
#  'Putting [something that cannot actually stand upright] upright on the table, so it falls on its side',
#  'Pretending to take [something] out of [something]',
#  '[Something] colliding with [something] and both are being deflected',
#  'Dropping [something] into [something]',
#  'Burying [something] in [something]',
#  'Pretending to put [something] into [something]',
#  'Putting [something] next to [something]',
#  'Pretending to open [something] without actually opening it',
#  'Pretending to scoop [something] up with [something]',
#  'Attaching [something] to [something]',
#  'Trying to bend [something unbendable] so nothing happens',
#  "Poking [something] so lightly that it doesn't or almost doesn't move",
#  'Spinning [something] that quickly stops spinning',
#  'Opening [something]',
#  'Moving [part] of [something]',
#  'Moving away from [something] with your camera',
#  'Plugging [something] into [something]',
#  'Turning [something] upside down',
#  'Uncovering [something]',
#  'Stuffing [something] into [something]',
#  'Showing a photo of [something] to the camera',
#  'Moving [something] and [something] so they pass each other',
#  'Pulling two ends of [something] so that it gets stretched',
#  'Turning the camera upwards while filming [something]',
#  'Piling [something] up',
#  'Poking [something] so that it falls over',
#  'Pretending to pick [something] up',
#  'Approaching [something] with your camera',
#  'Tearing [something] just a little bit',
#  'Bending [something] so that it deforms',
#  'Showing [something] on top of [something]',
#  'Pulling [something] from left to right',
#  'Lifting a surface with [something] on it but not enough for it to slide down',
#  'Moving [something] and [something] away from each other',
#  'Removing [something], revealing [something] behind',
#  'Lifting [something] up completely without letting it drop down',
#  'Bending [something] until it breaks',
#  'Pushing [something] with [something]',
#  'Pretending to put [something] onto [something]',
#  'Pretending to put [something] behind [something]',
#  'Picking [something] up',
#  '[Something] being deflected from [something]',
#  'Putting [something], [something] and [something] on the table',
#  "Putting [something] onto a slanted surface but it doesn't glide down",
#  'Pushing [something] so that it falls off the table',
#  'Taking [something] from [somewhere]',
#  'Dropping [something] next to [something]',
#  'Rolling [something] on a flat surface',
#  'Spinning [something] so it continues spinning',
#  'Unfolding [something]',
#  'Pretending to squeeze [something]',
#  'Trying to pour [something] into [something], but missing so it spills next to it',
#  'Pretending to close [something] without actually closing it',
#  'Stacking [number of] [something]',
#  'Pretending to sprinkle air onto [something]',
#  'Putting [number of] [something] onto [something]',
#  "Pushing [something] so that it almost falls off but doesn't",
#  'Putting [something] behind [something]',
#  'Moving [something] and [something] so they collide with each other',
#  'Pouring [something] out of [something]',
#  'Showing [something] to the camera',
#  'Throwing [something] onto a surface',
#  'Pretending to put [something] underneath [something]',
#  'Poking a hole into [something soft]',
#  'Pouring [something] into [something] until it overflows',
#  'Letting [something] roll up a slanted surface, so it rolls back down',
#  'Turning the camera left while filming [something]',
#  'Pretending to put [something] next to [something]',
#  'Poking [something] so it slightly moves',
#  'Turning the camera downwards while filming [something]',
#  "Putting [something] that can't roll onto a slanted surface, so it stays where it is",
#  'Pulling [something] onto [something]',
#  'Pretending to poke [something]',
#  'Letting [something] roll down a slanted surface',
#  'Holding [something] behind [something]',
#  'Pulling two ends of [something] but nothing happens',
#  'Closing [something]',
#  "Putting [something] that can't roll onto a slanted surface, so it slides down",
#  "Trying but failing to attach [something] to [something] because it doesn't stick",
#  'Pouring [something] into [something]',
#  'Putting [something] on a flat surface without letting it roll',
#  'Pretending or trying and failing to twist [something]',
#  'Pouring [something] onto [something]',
#  'Spilling [something] next to [something]',
#  'Tipping [something] with [something in it] over, so [something in it] falls out',
#  'Wiping [something] off of [something]',
#  'Digging [something] out of [something]',
#  'Spilling [something] behind [something]',
#  'Plugging [something] into [something] but pulling it right out as you remove your hand',
#  'Lifting a surface with [something] on it until it starts sliding down',
#  'Pushing [something] onto [something]',
#  'Pulling [something] from behind of [something]',
#  'Pretending to pour [something] out of [something], but [something] is empty',
#  'Pretending or failing to wipe [something] off of [something]',
#  'Pulling two ends of [something] so that it separates into two pieces',
#  'Turning the camera right while filming [something]',
#  "Tilting [something] with [something] on it slightly so it doesn't fall down",
#  '[Something] colliding with [something] and both come to a halt',
#  'Laying [something] on the table on its side, not upright',
#  'Pretending to spread air onto [something]',
#  'Poking a hole into [some substance]',
#  'Poking a stack of [something] so the stack collapses',
#  'Poking [something] so that it spins around']

# %%
# Function that chooses x random rows from the dataframe pool
def choose_random_templates(unique_templates, x):
    all_templates = []
    past_index = []
    #  loop x times chosing one row at a time
    for i in range(x):
        while True:
            random_index = random.randint(0, len(unique_templates)-1)
            if random_index not in past_index:
                past_index.append(random_index)
                break
        templates = unique_templates[random_index]
        all_templates.append(templates)
    return all_templates

# %%
unknown_templates = choose_random_templates(uni_template, 10)
print(unknown_templates)
# Out:
# ['Throwing [something] in the air and letting it fall', 'Pulling [something] onto [something]', 'Putting [something similar to other things that are already on the table]', 'Pretending to take [something] from [somewhere]', 'Turning the camera upwards while filming [something]', 'Rolling [something] on a flat surface', 'Pretending to take [something] out of [something]', 'Approaching [something] with your camera', 'Pulling two ends of [something] but nothing happens', 'Folding [something]']

# %%
def create_df_known_labels_atomic(pool, unknown_templates):

    # Filter the DataFrame to exclude rows with templates in the unknown_templates array
    known_labels = pool[~pool['template'].isin(unknown_templates)]
    unknown_labels = pool[pool['template'].isin(unknown_templates)]

    return known_labels, unknown_labels

# %%
known_labels, unknown_labels = create_df_known_labels_atomic(pool, unknown_templates)
print(known_labels)
# Out:
#             id                                              label
# 0        78687        holding potato next to vicks vaporub bottle  \
# 1        42326                     spreading margarine onto bread
# 2       100904                           putting pen on a surface
# 3        80715  lifting up one end of bottle, then letting it ...
# 4        34899                                       holding bulb
# ...        ...                                                ...
# 193685  151948                  moving car key towards the camera
# 193686  117425                           closing small freshmints
# 193687  157360                                  unfolding a shirt
# 193688  117478                                    moving glass up
# 193689   36585            plastic falling like a feather or paper
#
#                                                  template
# 0                 Holding [something] next to [something]  \
# 1                  Spreading [something] onto [something]
# 2                        Putting [something] on a surface
# 3       Lifting up one end of [something], then lettin...
# 4                                     Holding [something]
# ...                                                   ...
# 193685              Moving [something] towards the camera
# 193686                                Closing [something]
# 193687                              Unfolding [something]
# 193688                              Moving [something] up
# 193689        [Something] falling like a feather or paper
#
#                           placeholders                   nouns
# 0       [potato, vicks vaporub bottle]  [potato, vick, bottle]  \
# 1                   [margarine, bread]      [margarine, bread]
# 2                                [pen]                   [pen]
# 3                             [bottle]                [bottle]
# 4                               [bulb]                  [bulb]
# ...                                ...                     ...
# 193685                       [car key]              [car, key]
# 193686              [small freshmints]             [freshmint]
# 193687                       [a shirt]                 [shirt]
# 193688                         [glass]                  [glas]
# 193689                       [plastic]               [plastic]
#
#                            verbs
# 0                      [holding]
# 1                    [spreading]
# 2                      [putting]
# 3       [lifting, letting, drop]
# 4                      [holding]
# ...                          ...
# 193685                  [moving]
# 193686                 [closing]
# 193687               [unfolding]
# 193688                  [moving]
# 193689                 [falling]
#
# [182595 rows x 6 columns]

# %%
print(unknown_labels)
# Out:
#             id                                              label
# 9        66533                                folding paper towel  \
# 12      187992         pretending to take bottle from window side
# 19       37055  throwing sunscreen in the air and letting it fall
# 98      209369             pretending to take matchbox from shelf
# 101     148739                                   putting tweezers
# ...        ...                                                ...
# 193584   49392                                       putting keyd
# 193610  163771  putting a bell pepper with a group of bell pep...
# 193643  149405        throwing pen in the air and letting it fall
# 193675  110293          pretending to take screwdriver from floor
# 193678  122099     throwing a ball in the air and letting it fall
#
#                                                  template
# 9                                     Folding [something]  \
# 12        Pretending to take [something] from [somewhere]
# 19      Throwing [something] in the air and letting it...
# 98        Pretending to take [something] from [somewhere]
# 101     Putting [something similar to other things tha...
# ...                                                   ...
# 193584  Putting [something similar to other things tha...
# 193610  Putting [something similar to other things tha...
# 193643  Throwing [something] in the air and letting it...
# 193675    Pretending to take [something] from [somewhere]
# 193678  Throwing [something] in the air and letting it...
#
#                                         placeholders
# 9                                      [paper towel]  \
# 12                             [bottle, window side]
# 19                                       [sunscreen]
# 98                                 [matchbox, shelf]
# 101                                       [tweezers]
# ...                                              ...
# 193584                                        [keyd]
# 193610  [a bell pepper with a group of bell peppers]
# 193643                                         [pen]
# 193675                          [screwdriver, floor]
# 193678                                      [a ball]
#
#                                       nouns                      verbs
# 9                            [paper, towel]                  [folding]
# 12                           [bottle, side]         [pretending, take]
# 19                              [sunscreen]  [throwing, letting, fall]
# 98                        [matchbox, shelf]         [pretending, take]
# 101                               [tweezer]             [putting, are]
# ...                                     ...                        ...
# 193584                               [keyd]             [putting, are]
# 193610  [bell, pepper, group, bell, pepper]             [putting, are]
# 193643                                [pen]  [throwing, letting, fall]
# 193675                 [screwdriver, floor]         [pretending, take]
# 193678                               [ball]  [throwing, letting, fall]
#
# [11095 rows x 6 columns]

# %%
def atomic_open_set(known_labels, unknown_labels):
    # Split the known_labels dataframe into training and testing sets
    train_df = known_labels.sample(frac=0.7, random_state=42)
    print('size of train_df: ', len(train_df))
    test_df = known_labels.drop(train_df.index)
    print('size of test_df: ', len(test_df))
    
    # Append the unknown_labels dataframe to the test set
    # test_df = test_df.append(unknown_labels, ignore_index=True)
    test_df = pd.concat([test_df, unknown_labels], ignore_index=True)
    print('size of test_df: ', len(test_df))
    
    # Save the train and test dataframes to JSON files
    train_df.to_json('atomic_train.json', orient='records', lines=True)
    test_df.to_json('atomic_test.json', orient='records', lines=True)

atomic_open_set(known_labels, unknown_labels)
# Out:
# size of train_df:  127816
# size of test_df:  54779
# size of test_df:  65874

# %%
# Function that chooses x random rows from the dataframe pool
def choose_random_nouns(pool, x):
    all_nouns = []
    past_index = []
    count_all_nouns=0
    #  loop x times chosing one row at a time
    while True:
        while True:
            random_index = random.randint(0, len(pool)-1)
            nouns = pool['nouns'][random_index]
            # Flatten the nested list into a single list
            count_index_nouns = len(set([item for sublist in nouns for item in sublist if item not in ['', None]]))
            if (random_index not in past_index) and (count_all_nouns + count_index_nouns <= x):
                past_index.append(random_index)
                break
        all_nouns.append(nouns)
        count_all_nouns=len(set([item for sublist in all_nouns for item in sublist if item not in ['', None]]))
        if count_all_nouns == x:
            break
    print(count_all_nouns)
    return set([item for sublist in all_nouns for item in sublist if item not in ['', None]])

def choose_random_verbs(pool, x):
    all_verbs = []
    past_index = []
    count_all_verbs=0
    #  loop x times chosing one row at a time
    for i in range(x):
        while True:
            random_index = random.randint(0, len(pool)-1)
            verbs = pool['verbs'][random_index]
            count_index_verbs=len(set([item for sublist in verbs for item in sublist if item not in ['', None]]))
            if (random_index not in past_index) and (count_all_verbs + count_index_verbs <= x):
                past_index.append(random_index)
                break
        
        all_verbs.append(verbs)
        count_all_verbs=len(set([item for sublist in all_verbs for item in sublist if item not in ['', None]]))
    return all_verbs

# %%
unknown_nouns = choose_random_nouns(pool,10)
print(unknown_nouns)
# unknown_verbs = choose_random_verbs(pool,10)
# print(unknown_verbs)
# Out:
# 10
# {'walnut', 'cd', 'hair', 'comb', 'water', 'seat', 'clip', 'box', 'pen', 'k'}

# %%
def create_df_known_labels_unkv(pool, unknown_nouns):

    # flatten unknown_nouns list
    flat_unknown_nouns = list(chain.from_iterable(unknown_nouns))
    
    # filter pool dataframe
    known_labels = pool[~pool['nouns'].apply(lambda x: any(item for item in x if item in flat_unknown_nouns))]
    unknown_labels = pool[pool['nouns'].apply(lambda x: any(item for item in x if item in flat_unknown_nouns))]

    return known_labels, unknown_labels

# %%
known_labels, unknown_labels = create_df_known_labels_unkv(pool, unknown_nouns)
unknown_labels
# Out:
#             id                                              label
# 0        78687        holding potato next to vicks vaporub bottle  \
# 3        80715  lifting up one end of bottle, then letting it ...
# 9        66533                                folding paper towel
# 12      187992         pretending to take bottle from window side
# 18      134982             dropping headset in front of tools bag
# ...        ...                                                ...
# 193670   87849  pulling two ends of paper so that it separates...
# 193671   62096                          showing mug behind kettle
# 193672  171194                       dropping a loonie into a cup
# 193673   40391              paper falling like a feather or paper
# 193674  132103  a ply of toilet paper falling like a feather o...
#
#                                                  template
# 0                 Holding [something] next to [something]  \
# 3       Lifting up one end of [something], then lettin...
# 9                                     Folding [something]
# 12        Pretending to take [something] from [somewhere]
# 18           Dropping [something] in front of [something]
# ...                                                   ...
# 193670  Pulling two ends of [something] so that it sep...
# 193671             Showing [something] behind [something]
# 193672              Dropping [something] into [something]
# 193673        [Something] falling like a feather or paper
# 193674        [Something] falling like a feather or paper
#
#                           placeholders                   nouns
# 0       [potato, vicks vaporub bottle]  [potato, vick, bottle]  \
# 3                             [bottle]                [bottle]
# 9                        [paper towel]          [paper, towel]
# 12               [bottle, window side]          [bottle, side]
# 18                [headset, tools bag]    [headset, tool, bag]
# ...                                ...                     ...
# 193670                         [paper]                 [paper]
# 193671                   [mug, kettle]           [mug, kettle]
# 193672               [a loonie, a cup]           [loonie, cup]
# 193673                         [paper]                 [paper]
# 193674         [a ply of toilet paper]    [ply, toilet, paper]
#
#                            verbs
# 0                   [holding, []
# 3       [lifting, letting, drop]
# 9                      [folding]
# 12         [pretending, take, ]]
# 18                    [dropping]
# ...                          ...
# 193670      [pulling, separates]
# 193671                 [showing]
# 193672                [dropping]
# 193673                 [falling]
# 193674                 [falling]
#
# [39242 rows x 6 columns]

# %%
def unknown_noun_known_verb(known_labels, unknown_labels):
    # Find all unique verbs in known_labels and convert to set
    known_verbs = set(known_labels['verbs'].explode().unique())
    
    # Create a boolean mask of unknown_labels rows where any verb is not in known_verbs
    mask = ~(unknown_labels['verbs'].explode().isin(known_verbs)).groupby(level=0).any()
    
    # Filter out the rows where the mask is True
    unknown_labels = unknown_labels.loc[~mask]
    
    # Split the known_labels dataframe into training and testing sets
    train_df = known_labels.sample(frac=0.7, random_state=42)
    print('size of train_df: ', len(train_df))
    test_df = known_labels.drop(train_df.index)
    print('size of test_df: ', len(test_df))
    
    # Append the unknown_labels dataframe to the test set
    # test_df = test_df.append(unknown_labels, ignore_index=True)
    test_df = pd.concat([test_df, unknown_labels], ignore_index=True)
    print('size of test_df: ', len(test_df))
    
    # Save the train and test dataframes to JSON files
    train_df.to_json('unkv_train.json', orient='records', lines=True)
    test_df.to_json('unkv_test.json', orient='records', lines=True)

# %%
unknown_noun_known_verb(known_labels, unknown_labels)
# Out:
# size of train_df:  108114
# size of test_df:  46334
# size of test_df:  85576

# %%
def create_df_known_labels_knuv(pool, unknown_verbs):

    # flatten unknown_verbs list
    flat_unknown_verbs = list(chain.from_iterable(unknown_verbs))
    
    # filter pool dataframe
    known_labels = pool[~pool['verbs'].apply(lambda x: any(item for item in x if item in flat_unknown_verbs))]
    unknown_labels = pool[pool['verbs'].apply(lambda x: any(item for item in x if item in flat_unknown_verbs))]

    return known_labels, unknown_labels

# %%
def known_noun_unknown_verb(known_labels, unknown_labels):
    # Find all unique nouns in known_labels and convert to set
    known_nouns = set(known_labels['nouns'].explode().unique())
    
    # Create a boolean mask of unknown_labels rows where any nouns is not in known_nouns
    mask = ~(unknown_labels['nouns'].explode().isin(known_nouns)).groupby(level=0).any()
    
    # Filter out the rows where the mask is True
    unknown_labels = unknown_labels.loc[~mask]
    
    # Split the known_labels dataframe into training and testing sets
    train_df = known_labels.sample(frac=0.7, random_state=42)
    print('size of train_df: ', len(train_df))
    test_df = known_labels.drop(train_df.index)
    print('size of test_df: ', len(test_df))
    
    # Append the unknown_labels dataframe to the test set
    test_df = pd.concat([test_df, unknown_labels], ignore_index=True)
    print('size of test_df: ', len(test_df))
    
    # Save the train and test dataframes to JSON files
    train_df.to_json('knuv_train.json', orient='records', lines=True)
    test_df.to_json('knuv_test.json', orient='records', lines=True)

# %%
known_labels, unknown_labels = create_df_known_labels_knuv(pool, unknown_verbs)
known_noun_unknown_verb(known_labels, unknown_labels)
# Out:
# size of train_df:  75780
# size of test_df:  32477
# size of test_df:  117553

# %%
def create_df_known_labels_unuv(pool, unknown_nouns, unknown_verbs):

    # flatten unknown_nouns and unknown_verbs list
    flat_unknown_nouns = list(chain.from_iterable(unknown_nouns))
    flat_unknown_verbs = list(chain.from_iterable(unknown_verbs))
    
    
    # filter pool dataframe
    known_labels = pool[~pool['nouns'].apply(lambda x: any(item for item in x if item in flat_unknown_nouns))]
    known_labels = known_labels[~known_labels['verbs'].apply(lambda x: any(item for item in x if item in flat_unknown_verbs))]
    unknown_labels = pool[pool['nouns'].apply(lambda x: any(item for item in x if item in flat_unknown_nouns))]
    unknown_labels = unknown_labels[unknown_labels['verbs'].apply(lambda x: any(item for item in x if item in flat_unknown_verbs))]

    return known_labels, unknown_labels

# %%
def unknown_noun_unknown_verb(known_labels, unknown_labels):
    # Find all unique nouns in known_labels and convert to set
    known_nouns = set(known_labels['nouns'].explode().unique())
    known_verbs = set(known_labels['verbs'].explode().unique())
    
    # Create a boolean mask of unknown_labels rows where any nouns is not in known_nouns
    mask = ~(unknown_labels['nouns'].explode().isin(known_nouns)).groupby(level=0).any()
    
    # Filter out the rows where the mask is True
    unknown_labels = unknown_labels.loc[~mask]

    # Create a boolean mask of unknown_labels rows where any verb is not in known_verbs
    mask = ~(unknown_labels['verbs'].explode().isin(known_verbs)).groupby(level=0).any()

    # Filter out the rows where the mask is True
    unknown_labels = unknown_labels.loc[~mask]
    
    # Split the known_labels dataframe into training and testing sets
    train_df = known_labels.sample(frac=0.7, random_state=42)
    print('size of train_df: ', len(train_df))
    test_df = known_labels.drop(train_df.index)
    print('size of test_df: ', len(test_df))
    
    # Append the unknown_labels dataframe to the test set
    test_df = pd.concat([test_df, unknown_labels], ignore_index=True)
    print('size of test_df: ', len(test_df))
    
    # Save the train and test dataframes to JSON files
    train_df.to_json('unuv_train.json', orient='records', lines=True)
    test_df.to_json('unuv_test.json', orient='records', lines=True)

# %%
known_labels, unknown_labels = create_df_known_labels_unuv(pool, unknown_nouns, unknown_verbs)
unknown_noun_unknown_verb(known_labels, unknown_labels)
# Out:
# size of train_df:  58092
# size of test_df:  24897
# size of test_df:  27859
